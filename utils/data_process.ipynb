# %%
import os
import pandas as pd
import numpy as np
from scipy import interpolate

# %% [markdown]
# # 定义文件夹路径

# %%
ds_root_folder= '.\\DS'  # DS 文件夹路径
smarteye_root_folder = '.\\SmartEye'  # SmartEye 主文件夹路径（包含 SmartEye-No1 ~ SmartEye-No39）
output_folder = '.\\zrh'  # 插值后文件的输出路径

# %%
# 获取 DS 和 SmartEye 主文件夹中的实验者文件夹列表
ds_folders = [f for f in os.listdir(ds_root_folder) if os.path.isdir(os.path.join(ds_root_folder, f))]
smarteye_folders = [f for f in os.listdir(smarteye_root_folder) if os.path.isdir(os.path.join(smarteye_root_folder, f))]
print(ds_folders)
print(smarteye_folders)
# Out:
# ['No1', 'No10', 'No11', 'No12', 'No13', 'No14', 'No15', 'No16', 'No17', 'No18', 'No19', 'No2', 'No20', 'No21', 'No22', 'No23', 'No24', 'No25', 'No26', 'No27', 'No28', 'No29', 'No3', 'No30', 'No31', 'No32', 'No33', 'No34', 'No35', 'No36', 'No37', 'No4', 'No5', 'No6', 'No7', 'No8', 'No9']
# ['No1', 'No10', 'No11', 'No12', 'No13', 'No14', 'No15', 'No16', 'No17', 'No18', 'No19', 'No2', 'No20', 'No21', 'No22', 'No23', 'No24', 'No25', 'No26', 'No27', 'No28', 'No29', 'No3', 'No30', 'No31', 'No32', 'No33', 'No34', 'No35', 'No36', 'No37', 'No4', 'No5', 'No6', 'No7', 'No8', 'No9']

# %% [markdown]
# # 遍历每个实验者的文件夹

# %%
for ds_folder in ds_folders:
    participant_id = ds_folder.replace('No', '')  # 提取文件夹中的数字部分，例如从 'No1' 提取 '1'
    smarteye_folder = f"No{participant_id}"  # SmartEye 对应的文件夹名

    # 检查对应的 SmartEye 文件夹是否存在
    if smarteye_folder not in smarteye_folders:
        print(f"未找到与 {ds_folder} 对应的 SmartEye 文件夹")
        continue

    ds_folder_path = os.path.join(ds_root_folder, ds_folder)
    smarteye_folder_path = os.path.join(smarteye_root_folder, smarteye_folder)

    # 获取每个实验者文件夹中的 Excel 文件列表
    ds_file = [f for f in os.listdir(ds_folder_path) if f.endswith('.xlsx')][0]
    smarteye_files = [f for f in os.listdir(smarteye_folder_path) if f.endswith('.xlsx')]

    linear = {'EyelidOpening','GazeDirectionX','GazeDirectionY','PupilDiameter','movingGazeRatio'}
    nearest = {'Blink','Fixation','GazeObjects','Saccade','ScreenName'}

    # 遍历 DS 文件
    for smarteye_file in smarteye_files:
        smarteye_file_list = smarteye_file.split('_')
        datatype = smarteye_file_list[1]
        ds_file_path = os.path.join(ds_folder_path, ds_file)
        smarteye_file_path = os.path.join(smarteye_folder_path, smarteye_file)

        # 读取 DS 和 SmartEye 文件中的所有 sheet
        ds_data = pd.read_excel(ds_file_path, sheet_name=None)
        smarteye_data = pd.read_excel(smarteye_file_path, sheet_name=None)

        # 创建一个字典来保存插值后的 SmartEye 数据
        interpolated_smarteye_data = {}

        # 遍历 DS 的每个 sheet，按 DS 的行数对 SmartEye 进行插值
        for sheet_name, ds_df in ds_data.items():
            if sheet_name not in smarteye_data:
                print(f"SmartEye 文件中未找到对应的 sheet: {sheet_name}")
                continue

            # 获取 DS 文件的目标行数
            ds_row_count = ds_df.shape[0]

            # 获取 SmartEye 文件的行数
            smarteye_df = smarteye_data[sheet_name]
            smarteye_row_count = smarteye_df.shape[0]

            # 创建一个目标索引数组，行数为 DS 文件的行数
            smarteye_index = np.arange(smarteye_row_count)
            target_index = np.linspace(0, smarteye_row_count - 1, ds_row_count)

            # 创建一个空的 DataFrame 来保存插值后的结果
            interpolated_df = pd.DataFrame()

            # 对 SmartEye 数据的每一列进行插值
            for col in smarteye_df.columns:
                y = smarteye_df[col].values

                # 创建插值函数，线性插值
                kind = 'linear' if datatype in linear else 'nearest'
                f = interpolate.interp1d(smarteye_index, y, kind=kind, fill_value="extrapolate")

                # 计算插值后的结果
                interpolated_values = f(target_index)

                # 将插值结果保存到新的 DataFrame 中
                interpolated_df[col] = interpolated_values

            # 保存插值后的数据
            interpolated_smarteye_data[sheet_name] = interpolated_df

        # 将插值后的 SmartEye 数据保存到新的 Excel 文件中
        output_file_name = f"{smarteye_file[:-5]}_{kind}.xlsx"
        output_file_path = os.path.join(output_folder, smarteye_folder, output_file_name)
        
        with pd.ExcelWriter(output_file_path) as writer:
            for sheet_name, df in interpolated_smarteye_data.items():
                df.to_excel(writer, sheet_name=sheet_name, index=False)

        print(f"已处理并保存文件: {output_file_name}")
# Out:
# 已处理并保存文件: No1_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No1_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No1_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No1_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No1_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No1_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No1_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No1_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No1_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No1_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No1_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No1_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No10_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No10_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No10_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No10_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No10_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No10_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No10_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No10_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No10_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No10_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No10_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No10_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No11_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No11_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No11_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No11_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No11_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No11_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No11_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No11_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No11_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No11_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No11_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No11_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No12_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No12_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No12_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No12_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No12_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No12_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No12_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No12_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No12_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No12_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No12_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No12_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No13_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No13_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No13_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No13_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No13_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No13_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No13_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No13_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No13_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No13_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No13_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No13_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No14_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No14_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No14_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No14_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No14_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No14_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No14_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No14_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No14_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No14_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No14_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No14_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No15_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No15_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No15_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No15_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No15_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No15_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No15_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No15_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No15_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No15_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No15_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No15_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No16_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No16_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No16_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No16_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No16_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No16_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No16_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No16_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No16_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No16_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No16_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No16_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No17_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No17_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No17_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No17_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No17_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No17_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No17_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No17_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No17_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No17_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No17_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No17_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No18_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No18_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No18_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No18_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No18_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No18_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No18_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No18_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No18_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No18_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No18_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No18_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No19_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No19_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No19_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No19_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No19_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No19_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No19_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No19_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No19_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No19_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No19_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No19_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No2_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No2_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No2_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No2_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No2_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No2_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No2_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No2_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No2_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No2_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No2_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No2_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No20_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No20_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No20_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No20_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No20_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No20_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No20_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No20_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No20_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No20_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No20_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No20_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No21_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No21_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No21_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No21_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No21_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No21_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No21_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No21_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No21_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No21_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: No21_Saccade_recalculated(20231231)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No21_ScreenName_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No22_Blink_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No22_EyelidOpening_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No22_EyelidOpening_eachLaneChange_linear.xlsx
# 已处理并保存文件: No22_Fixation_recalculated(20240104)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No22_GazeDirectionX_eachLaneChange_linear.xlsx
# 已处理并保存文件: No22_GazeDirectionY_eachLaneChange_linear.xlsx
# 已处理并保存文件: No22_GazeObjects_recalculated(Reidentified+gap_filled)_eachLaneChange_nearest.xlsx
# 已处理并保存文件: No22_movingGazeRatio_eachLaneChange_transposed_linear.xlsx
# 已处理并保存文件: No22_PupilDiameter_Change_eachLaneChange_linear.xlsx
# 已处理并保存文件: No22_PupilDiameter_eachLaneChange_linear.xlsx
# 已处理并保存文件: